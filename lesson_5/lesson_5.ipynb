# %% [markdown]
# ## Тема "Предел функции"

# %%
from IPython.display import Image

# %%
Image('task_1.png')

# %% [markdown]
# ## Тема "Теоремы о пределах"

# %%
Image('task_2.png')

# %% [markdown]
# ## Тема “Понятие о производной”

# %%
Image('task_3.png')
