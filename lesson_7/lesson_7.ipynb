# %% [markdown]
# # Задание 1

# %% [markdown]
# Найти длину 𝑥 и ширину 𝑦
# прямоугольника при заданном
# периметре 𝑃=144 cм, при которых
# данный прямоугольник имеет
# наибольшую площадь 𝑆.

# %%
import sympy as sym
from IPython.display import Image

# %matplotlib inline

# %%
Image('task_7_1.png')

# %%
x, y = sym.symbols('x, y')

# %%
p = 2*(x + y)
p
# Out:
# 2*x + 2*y

# %%
s = x * y
s
# Out:
# x*y

# %% [markdown]
# Выразим переменную y через x и подставим в уравнение площади прямоугольника. Тогда задача будет сводиться к поиску экстремума полученной функции(максимума).

# %%
y_ = sym.solve(2*(x+y)-144, y)
y_
# Out:
# [72 - x]

# %%
s = s.subs(y, y_[0])
s
# Out:
# x*(72 - x)

# %%
def extremum(func):
    diff_f = sym.diff(func, x)
    try:
        if not sym.roots(diff_f, x):
            return print('Нет критических точек для поиска экстремума')
        roots = sym.roots(diff_f, x)
        r_min = min(sym.roots(diff_f, x).keys())
        r_max = max(sym.roots(diff_f, x).keys())
        sym.plot(func, (x, r_min-1, r_max+1), title='Function')
        sym.plot(diff_f, (x, r_min-1, r_max+1), title='Derivative')
        print(f"Корни уравнения: {list(roots.keys())}")
    except Exception:
        sym.plot(func, title='Function')
        print('Производная функция не имеет нулей')

# %%
extremum(s)
# Out:
# Корни уравнения: [36]

# %% [markdown]
# Таким образом, на графике фукции видно, что при х=36 достигается максимум площади прямоугольника, а на графике производной видно, что это критическая точка, в которой производная меняет знак с + на -.
# х = у = 36.

# %% [markdown]
# # Задание 2

# %%
Image('task_7_2.png')

# %% [markdown]
# 1. в точке х=0 поизводная не существует, но определена в окрестности этой точки и меняет знак. Следовательно, это минимум функции.
# 2. х=0 - нуль второго порядка, поэтому при прохождении через эту точку производная не меняет знак. Следовательно, данная критическая точка не является экстремумом.
# 3. производная не меняет знак, т.к. положительное число возведенное в любую степень остается положительным. У данной функции нет ни критической точки, ни экстремума.
# 4. экстремумы функции:
# х=-(5/3)^(1/2) - максимум
# х=(5/3)^(1/2) - минимум

# %%
extremum(abs(2*x))
# Out:
# Производная функция не имеет нулей

# %%
extremum(x**3)
# Out:
# Корни уравнения: [0]

# %%
extremum(sym.exp(3*x))
# Out:
# Производная функция не имеет нулей

# %%
extremum(x**3-5*x)
# Out:
# Корни уравнения: [-sqrt(15)/3, sqrt(15)/3]
